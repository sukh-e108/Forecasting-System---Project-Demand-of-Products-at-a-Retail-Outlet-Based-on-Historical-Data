# %%
import pandas as pd
import warnings
import matplotlib
import statsmodels.api as sm
import itertools 
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import matplotlib

# %%
sales1= pd.read_csv("DATA.csv")

# %% [markdown]
# ##### sales1

# %%
sales1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
sales1['Order Date']=pd.to_datetime(sales1['Order Date'],infer_datetime_format=True)
indexsales1=sales1.set_index(['Order Date'])
indexsales1.head(5)
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2017-08-11       1  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-08-11       2  CA-2017-152156  11/11/2017    Second Class    CG-12520
# 2017-12-06       3  CA-2017-138688  16/06/2017    Second Class    DV-13045
# 2016-11-10       4  US-2016-108966  18/10/2016  Standard Class    SO-20335
# 2016-11-10       5  US-2016-108966  18/10/2016  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2017-08-11      Claire Gute   Consumer  United States        Henderson
# 2017-08-11      Claire Gute   Consumer  United States        Henderson
# 2017-12-06  Darrin Van Huff  Corporate  United States      Los Angeles
# 2016-11-10   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2016-11-10   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                  State  Postal Code Region       Product ID         Category  \
# Order Date
# 2017-08-11    Kentucky      42420.0  South  FUR-BO-10001798        Furniture
# 2017-08-11    Kentucky      42420.0  South  FUR-CH-10000454        Furniture
# 2017-12-06  California      90036.0   West  OFF-LA-10000240  Office Supplies
# 2016-11-10     Florida      33311.0  South  FUR-TA-10000577        Furniture
# 2016-11-10     Florida      33311.0  South  OFF-ST-10000760  Office Supplies
#
#            Sub-Category                                       Product Name  \
# Order Date
# 2017-08-11    Bookcases                  Bush Somerset Collection Bookcase
# 2017-08-11       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2017-12-06       Labels  Self-Adhesive Address Labels for Typewriters b...
# 2016-11-10       Tables      Bretford CR4500 Series Slim Rectangular Table
# 2016-11-10      Storage                     Eldon Fold 'N Roll Cart System
#
#                Sales
# Order Date
# 2017-08-11  261.9600
# 2017-08-11  731.9400
# 2017-12-06   14.6200
# 2016-11-10  957.5775
# 2016-11-10   22.3680

# %%
cols=['Row ID' ,'Order ID',  'Ship Date', 'Ship Mode','Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State','Postal Code', 'Region', 'Product ID', 'Product Name']
indexsales1.drop(cols,axis=1,inplace=True)

# %%
indexsales1
# Out:
#                    Category Sub-Category     Sales
# Order Date
# 2017-08-11        Furniture    Bookcases  261.9600
# 2017-08-11        Furniture       Chairs  731.9400
# 2017-12-06  Office Supplies       Labels   14.6200
# 2016-11-10        Furniture       Tables  957.5775
# 2016-11-10  Office Supplies      Storage   22.3680
# ...                     ...          ...       ...
# 2017-05-21  Office Supplies      Binders    3.7980
# 2016-12-01  Office Supplies          Art   10.3680
# 2016-12-01       Technology       Phones  235.1880
# 2016-12-01       Technology       Phones   26.3760
# 2016-12-01       Technology  Accessories   10.3840
#
# [9800 rows x 3 columns]

# %%
indexsales1['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
indexsales1.isnull().sum()
# Out:
# Category        0
# Sub-Category    0
# Sales           0
# dtype: int64

# %%
furniture=indexsales1.loc[indexsales1['Category']=='Furniture']
furniture=furniture.sort_values('Order Date')
furniture=furniture.groupby('Order Date')['Sales'].sum().reset_index()
furniture=furniture.set_index('Order Date')
furniture.index
furniture
# Out:
#                 Sales
# Order Date
# 2015-01-03  1893.9950
# 2015-01-06  2024.0600
# 2015-01-08    44.1280
# 2015-01-11    31.6800
# 2015-01-12  4513.6060
# ...               ...
# 2018-12-24  1393.4940
# 2018-12-25   832.4540
# 2018-12-28   551.2568
# 2018-12-29  2330.7180
# 2018-12-30   323.1360
#
# [877 rows x 1 columns]

# %%
y_furniture=furniture['Sales'].resample('MS').mean()
furniture=pd.DataFrame({'Order Date':y_furniture.index,'Sales':y_furniture.values})
furniture
# Out:
#    Order Date        Sales
# 0  2015-01-01   924.024462
# 1  2015-02-01   248.475714
# 2  2015-03-01   778.884778
# 3  2015-04-01   525.167692
# 4  2015-05-01   390.457467
# 5  2015-06-01   611.823918
# 6  2015-07-01   601.328500
# 7  2015-08-01   762.809906
# 8  2015-09-01   844.152147
# 9  2015-10-01   818.771824
# 10 2015-11-01  1002.974167
# 11 2015-12-01  1380.420941
# 12 2016-01-01  1463.433262
# 13 2016-02-01   894.442556
# 14 2016-03-01   617.389662
# 15 2016-04-01   674.616300
# 16 2016-05-01   696.332806
# 17 2016-06-01   457.568789
# 18 2016-07-01   778.772438
# 19 2016-08-01   958.938643
# 20 2016-09-01  1452.349889
# 21 2016-10-01   758.091286
# 22 2016-11-01   836.532739
# 23 2016-12-01   716.510760
# 24 2017-01-01   613.566267
# 25 2017-02-01   557.091308
# 26 2017-03-01   806.122773
# 27 2017-04-01   584.444650
# 28 2017-05-01  1187.366147
# 29 2017-06-01   711.414500
# 30 2017-07-01   713.570353
# 31 2017-08-01   946.465800
# 32 2017-09-01   852.411695
# 33 2017-10-01   677.889150
# 34 2017-11-01   983.663476
# 35 2017-12-01  1273.200938
# 36 2018-01-01   976.935250
# 37 2018-02-01  1012.219150
# 38 2018-03-01   621.655512
# 39 2018-04-01   557.245886
# 40 2018-05-01   539.623495
# 41 2018-06-01   768.796432
# 42 2018-07-01   618.579114
# 43 2018-08-01   964.181818
# 44 2018-09-01   996.806227
# 45 2018-10-01   753.598800
# 46 2018-11-01  1242.404375
# 47 2018-12-01   973.765627

# %%
furniture=furniture.groupby('Order Date')['Sales'].sum().reset_index()
furniture=furniture.set_index('Order Date')
furniture
# Out:
#                   Sales
# Order Date
# 2015-01-01   924.024462
# 2015-02-01   248.475714
# 2015-03-01   778.884778
# 2015-04-01   525.167692
# 2015-05-01   390.457467
# 2015-06-01   611.823918
# 2015-07-01   601.328500
# 2015-08-01   762.809906
# 2015-09-01   844.152147
# 2015-10-01   818.771824
# 2015-11-01  1002.974167
# 2015-12-01  1380.420941
# 2016-01-01  1463.433262
# 2016-02-01   894.442556
# 2016-03-01   617.389662
# 2016-04-01   674.616300
# 2016-05-01   696.332806
# 2016-06-01   457.568789
# 2016-07-01   778.772438
# 2016-08-01   958.938643
# 2016-09-01  1452.349889
# 2016-10-01   758.091286
# 2016-11-01   836.532739
# 2016-12-01   716.510760
# 2017-01-01   613.566267
# 2017-02-01   557.091308
# 2017-03-01   806.122773
# 2017-04-01   584.444650
# 2017-05-01  1187.366147
# 2017-06-01   711.414500
# 2017-07-01   713.570353
# 2017-08-01   946.465800
# 2017-09-01   852.411695
# 2017-10-01   677.889150
# 2017-11-01   983.663476
# 2017-12-01  1273.200938
# 2018-01-01   976.935250
# 2018-02-01  1012.219150
# 2018-03-01   621.655512
# 2018-04-01   557.245886
# 2018-05-01   539.623495
# 2018-06-01   768.796432
# 2018-07-01   618.579114
# 2018-08-01   964.181818
# 2018-09-01   996.806227
# 2018-10-01   753.598800
# 2018-11-01  1242.404375
# 2018-12-01   973.765627

# %%
furniture['Sales'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
from statsmodels.tsa.stattools import adfuller
def ad_test(dataset):
     dftest = adfuller(dataset, autolag = 'AIC')
     print("1. ADF : ",dftest[0])
     print("2. P-Value : ", dftest[1])
     print("3. Num Of Lags : ", dftest[2])
     print("4. Num Of Observations Used For ADF Regression:",      dftest[3])
     print("5. Critical Values :")
     for key, val in dftest[4].items():
         print("\t",key, ": ", val)
ad_test(furniture['Sales'])
# Out:
# 1. ADF :  -4.05396376115166
# 2. P-Value :  0.0011528619101255277
# 3. Num Of Lags :  10
# 4. Num Of Observations Used For ADF Regression: 37
# 5. Critical Values :
# 	 1% :  -3.6209175221605827
# 	 5% :  -2.9435394610388332
# 	 10% :  -2.6104002410518627

# %%
from pylab import rcParams 
rcParams['figure.figsize']=18,8
decomposition=sm.tsa.seasonal_decompose(furniture,model='additive')
fig=decomposition.plot()
plt.show()

# %%
p=d=q=range(0,2)
pdq=list(itertools.product(p,d,q))
seasonal_pdq=[(x[0],x[1],x[2],12) for x in list(itertools.product(p,d,q))]
print('Examples of parameter combinatios for Seasonal ARIMA...')
print('SARIMAX:{}X{}'.format(pdq[1],seasonal_pdq[1]))
print('SARIMAX:{}X{}'.format(pdq[1],seasonal_pdq[2]))
print('SARIMAX:{}X{}'.format(pdq[2],seasonal_pdq[3]))
print('SARIMAX:{}X{}'.format(pdq[2],seasonal_pdq[4]))
# Out:
# Examples of parameter combinatios for Seasonal ARIMA...
# SARIMAX:(0, 0, 1)X(0, 0, 1, 12)
# SARIMAX:(0, 0, 1)X(0, 1, 0, 12)
# SARIMAX:(0, 1, 0)X(0, 1, 1, 12)
# SARIMAX:(0, 1, 0)X(1, 0, 0, 12)

# %%
for param in pdq :
    for param_seasonal in seasonal_pdq:
        try:
            mod =sm.tsa.statespace.SARIMAX(furniture['Sales'],order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results=mod.fit()
            print('ARIMA{}X{}12-AIC:{}'.format(param,param_seasonal,results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)X(0, 0, 0, 12)12-AIC:769.9073451818964
# ARIMA(0, 0, 0)X(0, 0, 1, 12)12-AIC:1644.573700158587
# ARIMA(0, 0, 0)X(0, 1, 0, 12)12-AIC:512.0648979435964
# ARIMA(0, 0, 0)X(0, 1, 1, 12)12-AIC:315.9084396682756
# ARIMA(0, 0, 0)X(1, 0, 0, 12)12-AIC:529.1321541418888
# ARIMA(0, 0, 0)X(1, 0, 1, 12)12-AIC:1457.4904244340848
# ARIMA(0, 0, 0)X(1, 1, 0, 12)12-AIC:334.0886901361257
# ARIMA(0, 0, 0)X(1, 1, 1, 12)12-AIC:317.89014232458766
# ARIMA(0, 0, 1)X(0, 0, 0, 12)12-AIC:717.1093133963244
# ARIMA(0, 0, 1)X(0, 0, 1, 12)12-AIC:2731.796216672444
# ARIMA(0, 0, 1)X(0, 1, 0, 12)12-AIC:494.42560067001517
# ARIMA(0, 0, 1)X(0, 1, 1, 12)12-AIC:302.2840561799651
# ARIMA(0, 0, 1)X(1, 0, 0, 12)12-AIC:526.425292427843
# ARIMA(0, 0, 1)X(1, 0, 1, 12)12-AIC:2702.6480863991596
# ARIMA(0, 0, 1)X(1, 1, 0, 12)12-AIC:336.0827327700041
# ARIMA(0, 0, 1)X(1, 1, 1, 12)12-AIC:304.26633241584966
# ARIMA(0, 1, 0)X(0, 0, 0, 12)12-AIC:652.9864396192831
# ARIMA(0, 1, 0)X(0, 0, 1, 12)12-AIC:1414.6899429821026
# ARIMA(0, 1, 0)X(0, 1, 0, 12)12-AIC:507.61303244651776
# ARIMA(0, 1, 0)X(0, 1, 1, 12)12-AIC:319.25681515667526
# ARIMA(0, 1, 0)X(1, 0, 0, 12)12-AIC:501.9275324311622
# ARIMA(0, 1, 0)X(1, 0, 1, 12)12-AIC:1519.4573321111695
# ARIMA(0, 1, 0)X(1, 1, 0, 12)12-AIC:335.4419713421551
# ARIMA(0, 1, 0)X(1, 1, 1, 12)12-AIC:320.5850098821865
# ARIMA(0, 1, 1)X(0, 0, 0, 12)12-AIC:632.1595552188032
# ARIMA(0, 1, 1)X(0, 0, 1, 12)12-AIC:1939.6477583054357
# ARIMA(0, 1, 1)X(0, 1, 0, 12)12-AIC:487.7737395884199
# ARIMA(0, 1, 1)X(0, 1, 1, 12)12-AIC:292.949596116185
# ARIMA(0, 1, 1)X(1, 0, 0, 12)12-AIC:499.04527197792555
# ARIMA(0, 1, 1)X(1, 0, 1, 12)12-AIC:2367.125830534083
# ARIMA(0, 1, 1)X(1, 1, 0, 12)12-AIC:325.37355949277344
# ARIMA(0, 1, 1)X(1, 1, 1, 12)12-AIC:297.43695943645326
# ARIMA(1, 0, 0)X(0, 0, 0, 12)12-AIC:672.0892481829643
# ARIMA(1, 0, 0)X(0, 0, 1, 12)12-AIC:1803.854032835875
# ARIMA(1, 0, 0)X(0, 1, 0, 12)12-AIC:509.2237785260867
# ARIMA(1, 0, 0)X(0, 1, 1, 12)12-AIC:317.8633250728853
# ARIMA(1, 0, 0)X(1, 0, 0, 12)12-AIC:501.302994129053
# ARIMA(1, 0, 0)X(1, 0, 1, 12)12-AIC:1555.3648145784966
# ARIMA(1, 0, 0)X(1, 1, 0, 12)12-AIC:318.0409946866597
# ARIMA(1, 0, 0)X(1, 1, 1, 12)12-AIC:319.8297940956787
# ARIMA(1, 0, 1)X(0, 0, 0, 12)12-AIC:650.4775760885641
# ARIMA(1, 0, 1)X(0, 0, 1, 12)12-AIC:320.86802023604434
# ARIMA(1, 0, 1)X(0, 1, 0, 12)12-AIC:495.72395239361276
# ARIMA(1, 0, 1)X(0, 1, 1, 12)12-AIC:304.281917917208
# ARIMA(1, 0, 1)X(1, 0, 0, 12)12-AIC:499.84892904271163
# ARIMA(1, 0, 1)X(1, 0, 1, 12)12-AIC:2606.481790957063
# ARIMA(1, 0, 1)X(1, 1, 0, 12)12-AIC:316.3516999914912
# ARIMA(1, 0, 1)X(1, 1, 1, 12)12-AIC:306.2632188831195
# ARIMA(1, 1, 0)X(0, 0, 0, 12)12-AIC:647.9088003584288
# ARIMA(1, 1, 0)X(0, 0, 1, 12)12-AIC:1264.4843534727088
# ARIMA(1, 1, 0)X(0, 1, 0, 12)12-AIC:505.29572364153944
# ARIMA(1, 1, 0)X(0, 1, 1, 12)12-AIC:312.9684589103753
# ARIMA(1, 1, 0)X(1, 0, 0, 12)12-AIC:482.7753160635003
# ARIMA(1, 1, 0)X(1, 0, 1, 12)12-AIC:1424.7955220801082
# ARIMA(1, 1, 0)X(1, 1, 0, 12)12-AIC:314.10390305607217
# ARIMA(1, 1, 0)X(1, 1, 1, 12)12-AIC:316.0771972696679
# ARIMA(1, 1, 1)X(0, 0, 0, 12)12-AIC:629.0429440689793
# ARIMA(1, 1, 1)X(0, 0, 1, 12)12-AIC:2387.0394960109597
# ARIMA(1, 1, 1)X(0, 1, 0, 12)12-AIC:489.0267841035802
# ARIMA(1, 1, 1)X(0, 1, 1, 12)12-AIC:294.623316237269
# ARIMA(1, 1, 1)X(1, 0, 0, 12)12-AIC:476.99984663140145
# ARIMA(1, 1, 1)X(1, 0, 1, 12)12-AIC:2255.1250593524164
# ARIMA(1, 1, 1)X(1, 1, 0, 12)12-AIC:311.4630511160449
# ARIMA(1, 1, 1)X(1, 1, 1, 12)12-AIC:296.25817804701256

# %%
train=furniture.iloc[:-20]
test=furniture.iloc[-20:]
print(train.shape,test.shape)
# Out:
# (28, 1) (20, 1)

# %%
test=test.groupby('Order Date')['Sales'].sum().reset_index()
test=test.set_index('Order Date')
test
# Out:
#                   Sales
# Order Date
# 2017-05-01  1187.366147
# 2017-06-01   711.414500
# 2017-07-01   713.570353
# 2017-08-01   946.465800
# 2017-09-01   852.411695
# 2017-10-01   677.889150
# 2017-11-01   983.663476
# 2017-12-01  1273.200938
# 2018-01-01   976.935250
# 2018-02-01  1012.219150
# 2018-03-01   621.655512
# 2018-04-01   557.245886
# 2018-05-01   539.623495
# 2018-06-01   768.796432
# 2018-07-01   618.579114
# 2018-08-01   964.181818
# 2018-09-01   996.806227
# 2018-10-01   753.598800
# 2018-11-01  1242.404375
# 2018-12-01   973.765627

# %%
mod =sm.tsa.statespace.SARIMAX(train['Sales'],order=(1,1,1),seasonal_order=(1,1,1,12),enforce_invertibility=False)
results=mod.fit()

# %%
start=len(train)
end=len(train)+len(test)-1
pred=results.predict(start=start,end=end,typ='levels')
pred.index=furniture.index[start:end+1]
print(pred)
# Out:
# Order Date
# 2017-05-01     499.219116
# 2017-06-01     603.467257
# 2017-07-01     678.271205
# 2017-08-01     842.477784
# 2017-09-01    1021.785774
# 2017-10-01     835.509425
# 2017-11-01     982.870691
# 2017-12-01    1219.476501
# 2018-01-01    1297.864554
# 2018-02-01     674.969545
# 2018-03-01     720.736604
# 2018-04-01     655.442872
# 2018-05-01     614.386422
# 2018-06-01     562.218503
# 2018-07-01     747.425876
# 2018-08-01     918.524465
# 2018-09-01    1239.365817
# 2018-10-01     823.931764
# 2018-11-01     940.186735
# 2018-12-01    1015.941464
# Name: predicted_mean, dtype: float64

# %%
pred.plot(legend=True)
test['Sales'].plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(pred,test)
# Out:
# 50685.799116063674

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse=sqrt(mean_squared_error(pred,test))
print(rmse)
# Out:
# 225.13506860563433

# %%
mod =sm.tsa.statespace.SARIMAX(furniture['Sales'],order=(1,1,1),seasonal_order=(1,1,1,12),enforce_invertibility=False)
results2=mod.fit()

# %%
furniture.tail()
# Out:
#                   Sales
# Order Date
# 2018-08-01   964.181818
# 2018-09-01   996.806227
# 2018-10-01   753.598800
# 2018-11-01  1242.404375
# 2018-12-01   973.765627

# %%
furniture.shape
# Out:
# (48, 1)

# %%
pred1=results2.get_forecast(steps=72)
predc=pred1.conf_int()
ax=furniture.plot(label='observed',figsize=(14,7))
pred1.predicted_mean.plot(ax=ax,label='Forecast')
ax.fill_between(predc.index,predc.iloc[:,0],predc.iloc[:,1],color='k',alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()
plt.show()

# %%
technology =indexsales1.loc[indexsales1['Category']=='Technology']
technology=technology.sort_values('Order Date')
technology=technology.groupby('Order Date')['Sales'].sum().reset_index()
technology=technology.set_index('Order Date')
technology
# Out:
#               Sales
# Order Date
# 2015-01-02  468.900
# 2015-01-03    5.940
# 2015-01-06  881.930
# 2015-01-07  575.920
# 2015-01-09  357.000
# ...             ...
# 2018-12-25  401.208
# 2018-12-27  164.388
# 2018-12-28   14.850
# 2018-12-29  302.376
# 2018-12-30   90.930
#
# [819 rows x 1 columns]

# %%
y_technology=technology['Sales'].resample('MS').mean()
technology=pd.DataFrame({'Order Date':y_technology.index,'Sales':y_technology.values})
technology
# Out:
#    Order Date        Sales
# 0  2015-01-01   700.040000
# 1  2015-02-01   503.799000
# 2  2015-03-01  2183.300800
# 3  2015-04-01   942.553000
# 4  2015-05-01   399.747368
# 5  2015-06-01   546.378600
# 6  2015-07-01   600.016167
# 7  2015-08-01  1291.196308
# 8  2015-09-01  1424.456235
# 9  2015-10-01   855.612400
# 10 2015-11-01   946.022909
# 11 2015-12-01  1307.021733
# 12 2016-01-01   873.807500
# 13 2016-02-01   620.877818
# 14 2016-03-01   532.882556
# 15 2016-04-01   956.900375
# 16 2016-05-01   610.715833
# 17 2016-06-01   638.741333
# 18 2016-07-01   706.300000
# 19 2016-08-01  1722.770857
# 20 2016-09-01  1134.077000
# 21 2016-10-01   611.083333
# 22 2016-11-01   538.016955
# 23 2016-12-01  1377.831333
# 24 2017-01-01   837.282267
# 25 2017-02-01  3651.381556
# 26 2017-03-01   575.339667
# 27 2017-04-01  1033.014400
# 28 2017-05-01  1522.818471
# 29 2017-06-01   876.069316
# 30 2017-07-01   956.665167
# 31 2017-08-01   635.795500
# 32 2017-09-01   426.016100
# 33 2017-10-01  1083.918294
# 34 2017-11-01  1326.039478
# 35 2017-12-01   821.522053
# 36 2018-01-01  1200.383632
# 37 2018-02-01   959.287263
# 38 2018-03-01  1769.617913
# 39 2018-04-01  1239.360786
# 40 2018-05-01   770.926952
# 41 2018-06-01   907.015059
# 42 2018-07-01  1002.076769
# 43 2018-08-01  1147.733500
# 44 2018-09-01  1061.983500
# 45 2018-10-01  1199.745667
# 46 2018-11-01  1334.547208
# 47 2018-12-01   719.515684

# %%
technology=technology.groupby('Order Date')['Sales'].sum().reset_index()
technology=technology.set_index('Order Date')
technology
# Out:
#                   Sales
# Order Date
# 2015-01-01   700.040000
# 2015-02-01   503.799000
# 2015-03-01  2183.300800
# 2015-04-01   942.553000
# 2015-05-01   399.747368
# 2015-06-01   546.378600
# 2015-07-01   600.016167
# 2015-08-01  1291.196308
# 2015-09-01  1424.456235
# 2015-10-01   855.612400
# 2015-11-01   946.022909
# 2015-12-01  1307.021733
# 2016-01-01   873.807500
# 2016-02-01   620.877818
# 2016-03-01   532.882556
# 2016-04-01   956.900375
# 2016-05-01   610.715833
# 2016-06-01   638.741333
# 2016-07-01   706.300000
# 2016-08-01  1722.770857
# 2016-09-01  1134.077000
# 2016-10-01   611.083333
# 2016-11-01   538.016955
# 2016-12-01  1377.831333
# 2017-01-01   837.282267
# 2017-02-01  3651.381556
# 2017-03-01   575.339667
# 2017-04-01  1033.014400
# 2017-05-01  1522.818471
# 2017-06-01   876.069316
# 2017-07-01   956.665167
# 2017-08-01   635.795500
# 2017-09-01   426.016100
# 2017-10-01  1083.918294
# 2017-11-01  1326.039478
# 2017-12-01   821.522053
# 2018-01-01  1200.383632
# 2018-02-01   959.287263
# 2018-03-01  1769.617913
# 2018-04-01  1239.360786
# 2018-05-01   770.926952
# 2018-06-01   907.015059
# 2018-07-01  1002.076769
# 2018-08-01  1147.733500
# 2018-09-01  1061.983500
# 2018-10-01  1199.745667
# 2018-11-01  1334.547208
# 2018-12-01   719.515684

# %%
technology['Sales'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
ad_test(technology['Sales'])
# Out:
# 1. ADF :  -7.368123278099122
# 2. P-Value :  9.12166320862809e-11
# 3. Num Of Lags :  0
# 4. Num Of Observations Used For ADF Regression: 47
# 5. Critical Values :
# 	 1% :  -3.5778480370438146
# 	 5% :  -2.925338105429433
# 	 10% :  -2.6007735310095064

# %%
from pylab import rcParams 
rcParams['figure.figsize']=18,8
decomposition=sm.tsa.seasonal_decompose(technology,model='additive')
fig=decomposition.plot()
plt.show()

# %%
p=d=q=range(0,2)
pdq=list(itertools.product(p,d,q))
seasonal_pdq=[(x[0],x[1],x[2],12) for x in list(itertools.product(p,d,q))]
print('Examples of parameter combinatios for Seasonal ARIMA...')
print('SARIMAX:{}X{}'.format(pdq[1],seasonal_pdq[1]))
print('SARIMAX:{}X{}'.format(pdq[1],seasonal_pdq[2]))
print('SARIMAX:{}X{}'.format(pdq[2],seasonal_pdq[3]))
print('SARIMAX:{}X{}'.format(pdq[2],seasonal_pdq[4]))
# Out:
# Examples of parameter combinatios for Seasonal ARIMA...
# SARIMAX:(0, 0, 1)X(0, 0, 1, 12)
# SARIMAX:(0, 0, 1)X(0, 1, 0, 12)
# SARIMAX:(0, 1, 0)X(0, 1, 1, 12)
# SARIMAX:(0, 1, 0)X(1, 0, 0, 12)

# %%
for param in pdq :
    for param_seasonal in seasonal_pdq:
        try:
            mod =sm.tsa.statespace.SARIMAX(technology['Sales'],order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results=mod.fit()
            print('ARIMA{}X{}12-AIC:{}'.format(param,param_seasonal,results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)X(0, 0, 0, 12)12-AIC:798.8271282919636
# ARIMA(0, 0, 0)X(0, 0, 1, 12)12-AIC:1403.7768462033666
# ARIMA(0, 0, 0)X(0, 1, 0, 12)12-AIC:574.9880253518048
# ARIMA(0, 0, 0)X(0, 1, 1, 12)12-AIC:376.8263115874772
# ARIMA(0, 0, 0)X(1, 0, 0, 12)12-AIC:587.6711884879505
# ARIMA(0, 0, 0)X(1, 0, 1, 12)12-AIC:1383.406782213698
# ARIMA(0, 0, 0)X(1, 1, 0, 12)12-AIC:395.5513150032792
# ARIMA(0, 0, 0)X(1, 1, 1, 12)12-AIC:378.80415945955906
# ARIMA(0, 0, 1)X(0, 0, 0, 12)12-AIC:764.9405584642694
# ARIMA(0, 0, 1)X(0, 0, 1, 12)12-AIC:2728.345473905928
# ARIMA(0, 0, 1)X(0, 1, 0, 12)12-AIC:560.9266923205743
# ARIMA(0, 0, 1)X(0, 1, 1, 12)12-AIC:341.51279333474145
# ARIMA(0, 0, 1)X(1, 0, 0, 12)12-AIC:589.6283035638478
# ARIMA(0, 0, 1)X(1, 0, 1, 12)12-AIC:2561.6339691572985
# ARIMA(0, 0, 1)X(1, 1, 0, 12)12-AIC:396.54426243888946
# ARIMA(0, 0, 1)X(1, 1, 1, 12)12-AIC:342.5000618095508
# ARIMA(0, 1, 0)X(0, 0, 0, 12)12-AIC:748.1412946320693
# ARIMA(0, 1, 0)X(0, 0, 1, 12)12-AIC:1127.619732160309
# ARIMA(0, 1, 0)X(0, 1, 0, 12)12-AIC:587.46260625866
# ARIMA(0, 1, 0)X(0, 1, 1, 12)12-AIC:371.0083011875653
# ARIMA(0, 1, 0)X(1, 0, 0, 12)12-AIC:572.8733528346104
# ARIMA(0, 1, 0)X(1, 0, 1, 12)12-AIC:886.6511814148943
# ARIMA(0, 1, 0)X(1, 1, 0, 12)12-AIC:400.34876530790586
# ARIMA(0, 1, 0)X(1, 1, 1, 12)12-AIC:372.4624677803634
# ARIMA(0, 1, 1)X(0, 0, 0, 12)12-AIC:697.622037734081
# ARIMA(0, 1, 1)X(0, 0, 1, 12)12-AIC:1733.3822879108425
# ARIMA(0, 1, 1)X(0, 1, 0, 12)12-AIC:544.9198245152832
# ARIMA(0, 1, 1)X(0, 1, 1, 12)12-AIC:325.80507947948394
# ARIMA(0, 1, 1)X(1, 0, 0, 12)12-AIC:550.2357539393611
# ARIMA(0, 1, 1)X(1, 0, 1, 12)12-AIC:2165.749334096243
# ARIMA(0, 1, 1)X(1, 1, 0, 12)12-AIC:383.4596217080054
# ARIMA(0, 1, 1)X(1, 1, 1, 12)12-AIC:327.01597696130375
# ARIMA(1, 0, 0)X(0, 0, 0, 12)12-AIC:759.5357617358551
# ARIMA(1, 0, 0)X(0, 0, 1, 12)12-AIC:1437.8100184540867
# ARIMA(1, 0, 0)X(0, 1, 0, 12)12-AIC:576.3517232059247
# ARIMA(1, 0, 0)X(0, 1, 1, 12)12-AIC:378.41776456387504
# ARIMA(1, 0, 0)X(1, 0, 0, 12)12-AIC:570.9533912844406
# ARIMA(1, 0, 0)X(1, 0, 1, 12)12-AIC:1110.8589845223653
# ARIMA(1, 0, 0)X(1, 1, 0, 12)12-AIC:381.22045283882545
# ARIMA(1, 0, 0)X(1, 1, 1, 12)12-AIC:380.4127589750625
# ARIMA(1, 0, 1)X(0, 0, 0, 12)12-AIC:720.7380507411598
# ARIMA(1, 0, 1)X(0, 0, 1, 12)12-AIC:2011.0078875203103
# ARIMA(1, 0, 1)X(0, 1, 0, 12)12-AIC:561.9751497850771
# ARIMA(1, 0, 1)X(0, 1, 1, 12)12-AIC:341.44036581971534
# ARIMA(1, 0, 1)X(1, 0, 0, 12)12-AIC:553.1623063047901
# ARIMA(1, 0, 1)X(1, 0, 1, 12)12-AIC:2561.105595407153
# ARIMA(1, 0, 1)X(1, 1, 0, 12)12-AIC:383.16399059057505
# ARIMA(1, 0, 1)X(1, 1, 1, 12)12-AIC:342.9483386049256
# ARIMA(1, 1, 0)X(0, 0, 0, 12)12-AIC:735.9886238743641
# ARIMA(1, 1, 0)X(0, 0, 1, 12)12-AIC:1249.6289721250344
# ARIMA(1, 1, 0)X(0, 1, 0, 12)12-AIC:577.4318209511725
# ARIMA(1, 1, 0)X(0, 1, 1, 12)12-AIC:363.00408809020655
# ARIMA(1, 1, 0)X(1, 0, 0, 12)12-AIC:546.5179836234155
# ARIMA(1, 1, 0)X(1, 0, 1, 12)12-AIC:1164.9189726444336
# ARIMA(1, 1, 0)X(1, 1, 0, 12)12-AIC:369.33739266819083
# ARIMA(1, 1, 0)X(1, 1, 1, 12)12-AIC:364.64343941081495
# ARIMA(1, 1, 1)X(0, 0, 0, 12)12-AIC:699.3072209471794
# ARIMA(1, 1, 1)X(0, 0, 1, 12)12-AIC:415.7163682560704
# ARIMA(1, 1, 1)X(0, 1, 0, 12)12-AIC:546.352881221335
# ARIMA(1, 1, 1)X(0, 1, 1, 12)12-AIC:327.80181533784156
# ARIMA(1, 1, 1)X(1, 0, 0, 12)12-AIC:537.169236917332
# ARIMA(1, 1, 1)X(1, 0, 1, 12)12-AIC:570.265742245936
# ARIMA(1, 1, 1)X(1, 1, 0, 12)12-AIC:358.39018906201704
# ARIMA(1, 1, 1)X(1, 1, 1, 12)12-AIC:328.7802279526917

# %%
train=technology.iloc[:-20]
test=technology.iloc[-20:]
print(train.shape,test.shape)
# Out:
# (28, 1) (20, 1)

# %%
test=test.groupby('Order Date')['Sales'].sum().reset_index()
test=test.set_index('Order Date')
test
# Out:
#                   Sales
# Order Date
# 2017-05-01  1522.818471
# 2017-06-01   876.069316
# 2017-07-01   956.665167
# 2017-08-01   635.795500
# 2017-09-01   426.016100
# 2017-10-01  1083.918294
# 2017-11-01  1326.039478
# 2017-12-01   821.522053
# 2018-01-01  1200.383632
# 2018-02-01   959.287263
# 2018-03-01  1769.617913
# 2018-04-01  1239.360786
# 2018-05-01   770.926952
# 2018-06-01   907.015059
# 2018-07-01  1002.076769
# 2018-08-01  1147.733500
# 2018-09-01  1061.983500
# 2018-10-01  1199.745667
# 2018-11-01  1334.547208
# 2018-12-01   719.515684

# %%
mod =sm.tsa.statespace.SARIMAX(train['Sales'],order=(1,1,1),seasonal_order=(1,1,1,12),enforce_invertibility=False)
results=mod.fit()
print(results.summary().tables[1])
results.plot_diagnostics()
plt.show()
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0506      1.435     -0.035      0.972      -2.863       2.762
# ma.L1         -1.0000   1.69e+04  -5.93e-05      1.000   -3.31e+04    3.31e+04
# ar.S.L12       0.5154      9.279      0.056      0.956     -17.670      18.701
# ma.S.L12      -1.0002   1.69e+04  -5.93e-05      1.000    -3.3e+04     3.3e+04
# sigma2      6.491e+05      0.004   1.81e+08      0.000    6.49e+05    6.49e+05
# ==============================================================================

# %%
start=len(train)
end=len(train)+len(test)-1
pred=results.predict(start=start,end=end,typ='levels')
pred.index=technology.index[start:end+1]
print(pred)
# Out:
# Order Date
# 2017-05-01     809.446948
# 2017-06-01     835.328558
# 2017-07-01     915.170368
# 2017-08-01    1769.123129
# 2017-09-01    1367.795752
# 2017-10-01     898.853459
# 2017-11-01     844.258825
# 2017-12-01    1470.652710
# 2018-01-01    1078.601148
# 2018-02-01    2989.328835
# 2018-03-01    1059.777487
# 2018-04-01    1253.754107
# 2018-05-01     984.981530
# 2018-06-01    1015.238285
# 2018-07-01    1101.133441
# 2018-08-01    1871.342945
# 2018-09-01    1566.578281
# 2018-10-01    1125.492584
# 2018-11-01    1080.417766
# 2018-12-01    1596.820723
# Name: predicted_mean, dtype: float64

# %%
pred.plot(legend=True)
test['Sales'].plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(pred,test)
# Out:
# 484835.16708224016

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse=sqrt(mean_squared_error(pred,test))
print(rmse)
# Out:
# 696.3010606643079

# %%
mod =sm.tsa.statespace.SARIMAX(technology['Sales'],order=(1,1,1),seasonal_order=(1,1,1,12),enforce_invertibility=False)
results2=mod.fit()

# %%
technology.tail()
# Out:
#                   Sales
# Order Date
# 2018-08-01  1147.733500
# 2018-09-01  1061.983500
# 2018-10-01  1199.745667
# 2018-11-01  1334.547208
# 2018-12-01   719.515684

# %%
technology.shape
# Out:
# (48, 1)

# %%
pred1=results2.get_forecast(steps=72)
predc=pred1.conf_int()
ax=technology.plot(label='observed',figsize=(14,7))
pred1.predicted_mean.plot(ax=ax,label='Forecast')
ax.fill_between(predc.index,predc.iloc[:,0],predc.iloc[:,1],color='k',alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Technology Sales')
plt.legend()
plt.show()

# %%
office_supplies =indexsales1.loc[indexsales1['Category']=='Office Supplies']
office_supplies=office_supplies.sort_values('Order Date')
office_supplies=office_supplies.groupby('Order Date')['Sales'].sum().reset_index()
office_supplies=office_supplies.set_index('Order Date')
office_supplies
# Out:
#                Sales
# Order Date
# 2015-01-03   303.216
# 2015-01-04   119.888
# 2015-01-06  2282.530
# 2015-01-07    25.104
# 2015-01-08   184.200
# ...              ...
# 2018-12-26   814.594
# 2018-12-27    13.248
# 2018-12-28  1091.244
# 2018-12-29   282.440
# 2018-12-30   299.724
#
# [1143 rows x 1 columns]

# %%
y_office_supplies=office_supplies['Sales'].resample('MS').mean()
office_supplies=pd.DataFrame({'Order Date':y_office_supplies.index,'Sales':y_office_supplies.values})
office_supplies
# Out:
#    Order Date        Sales
# 0  2015-01-01   442.918737
# 1  2015-02-01   218.343909
# 2  2015-03-01   302.427250
# 3  2015-04-01   352.387750
# 4  2015-05-01   698.627304
# 5  2015-06-01   504.030905
# 6  2015-07-01   725.808818
# 7  2015-08-01   439.934474
# 8  2015-09-01   988.528962
# 9  2015-10-01   339.506087
# 10 2015-11-01   899.779800
# 11 2015-12-01   591.031478
# 12 2016-01-01   222.152933
# 13 2016-02-01   324.928500
# 14 2016-03-01   653.024217
# 15 2016-04-01   526.138250
# 16 2016-05-01   419.191462
# 17 2016-06-01   563.081579
# 18 2016-07-01   282.943227
# 19 2016-08-01   524.227136
# 20 2016-09-01   635.736885
# 21 2016-10-01   493.848375
# 22 2016-11-01   757.300760
# 23 2016-12-01   356.563333
# 24 2017-01-01   814.272800
# 25 2017-02-01   440.148450
# 26 2017-03-01   835.973040
# 27 2017-04-01   400.754680
# 28 2017-05-01   585.299321
# 29 2017-06-01   432.782440
# 30 2017-07-01   539.620609
# 31 2017-08-01   451.287640
# 32 2017-09-01   559.121958
# 33 2017-10-01   877.068000
# 34 2017-11-01   586.027154
# 35 2017-12-01  1026.205538
# 36 2018-01-01   853.153520
# 37 2018-02-01   659.403136
# 38 2018-03-01   660.929429
# 39 2018-04-01   351.840040
# 40 2018-05-01   555.389769
# 41 2018-06-01   560.771923
# 42 2018-07-01   571.201560
# 43 2018-08-01  1378.194154
# 44 2018-09-01   994.999643
# 45 2018-10-01   854.620462
# 46 2018-11-01  1005.800077
# 47 2018-12-01   780.914071

# %%
office_supplies=office_supplies.groupby('Order Date')['Sales'].sum().reset_index()
office_supplies=office_supplies.set_index('Order Date')
office_supplies
# Out:
#                   Sales
# Order Date
# 2015-01-01   442.918737
# 2015-02-01   218.343909
# 2015-03-01   302.427250
# 2015-04-01   352.387750
# 2015-05-01   698.627304
# 2015-06-01   504.030905
# 2015-07-01   725.808818
# 2015-08-01   439.934474
# 2015-09-01   988.528962
# 2015-10-01   339.506087
# 2015-11-01   899.779800
# 2015-12-01   591.031478
# 2016-01-01   222.152933
# 2016-02-01   324.928500
# 2016-03-01   653.024217
# 2016-04-01   526.138250
# 2016-05-01   419.191462
# 2016-06-01   563.081579
# 2016-07-01   282.943227
# 2016-08-01   524.227136
# 2016-09-01   635.736885
# 2016-10-01   493.848375
# 2016-11-01   757.300760
# 2016-12-01   356.563333
# 2017-01-01   814.272800
# 2017-02-01   440.148450
# 2017-03-01   835.973040
# 2017-04-01   400.754680
# 2017-05-01   585.299321
# 2017-06-01   432.782440
# 2017-07-01   539.620609
# 2017-08-01   451.287640
# 2017-09-01   559.121958
# 2017-10-01   877.068000
# 2017-11-01   586.027154
# 2017-12-01  1026.205538
# 2018-01-01   853.153520
# 2018-02-01   659.403136
# 2018-03-01   660.929429
# 2018-04-01   351.840040
# 2018-05-01   555.389769
# 2018-06-01   560.771923
# 2018-07-01   571.201560
# 2018-08-01  1378.194154
# 2018-09-01   994.999643
# 2018-10-01   854.620462
# 2018-11-01  1005.800077
# 2018-12-01   780.914071

# %%
office_supplies['Sales'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
ad_test(office_supplies['Sales'])
# Out:
# 1. ADF :  -2.8519517678982327
# 2. P-Value :  0.05122744844475518
# 3. Num Of Lags :  1
# 4. Num Of Observations Used For ADF Regression: 46
# 5. Critical Values :
# 	 1% :  -3.5812576580093696
# 	 5% :  -2.9267849124681518
# 	 10% :  -2.6015409829867675

# %%
from pylab import rcParams 
rcParams['figure.figsize']=18,8
decomposition=sm.tsa.seasonal_decompose(office_supplies,model='additive')
fig=decomposition.plot()
plt.show()

# %%
p=d=q=range(0,2)
pdq=list(itertools.product(p,d,q))
seasonal_pdq=[(x[0],x[1],x[2],12) for x in list(itertools.product(p,d,q))]
print('Examples of parameter combinatios for Seasonal ARIMA...')
print('SARIMAX:{}X{}'.format(pdq[1],seasonal_pdq[1]))
print('SARIMAX:{}X{}'.format(pdq[1],seasonal_pdq[2]))
print('SARIMAX:{}X{}'.format(pdq[2],seasonal_pdq[3]))
print('SARIMAX:{}X{}'.format(pdq[2],seasonal_pdq[4]))
# Out:
# Examples of parameter combinatios for Seasonal ARIMA...
# SARIMAX:(0, 0, 1)X(0, 0, 1, 12)
# SARIMAX:(0, 0, 1)X(0, 1, 0, 12)
# SARIMAX:(0, 1, 0)X(0, 1, 1, 12)
# SARIMAX:(0, 1, 0)X(1, 0, 0, 12)

# %%
for param in pdq :
    for param_seasonal in seasonal_pdq:
        try:
            mod =sm.tsa.statespace.SARIMAX(office_supplies['Sales'],order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results=mod.fit()
            print('ARIMA{}X{}12-AIC:{}'.format(param,param_seasonal,results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)X(0, 0, 0, 12)12-AIC:744.9374231679759
# ARIMA(0, 0, 0)X(0, 0, 1, 12)12-AIC:1410.191468821238
# ARIMA(0, 0, 0)X(0, 1, 0, 12)12-AIC:501.3497718660246
# ARIMA(0, 0, 0)X(0, 1, 1, 12)12-AIC:331.21109493161623
# ARIMA(0, 0, 0)X(1, 0, 0, 12)12-AIC:517.094204505464
# ARIMA(0, 0, 0)X(1, 0, 1, 12)12-AIC:1282.2632178880237
# ARIMA(0, 0, 0)X(1, 1, 0, 12)12-AIC:347.739509498382
# ARIMA(0, 0, 0)X(1, 1, 1, 12)12-AIC:332.25115623004723
# ARIMA(0, 0, 1)X(0, 0, 0, 12)12-AIC:705.3863369545277
# ARIMA(0, 0, 1)X(0, 0, 1, 12)12-AIC:2790.752598672211
# ARIMA(0, 0, 1)X(0, 1, 0, 12)12-AIC:489.89647172929494
# ARIMA(0, 0, 1)X(0, 1, 1, 12)12-AIC:319.208605132564
# ARIMA(0, 0, 1)X(1, 0, 0, 12)12-AIC:518.865053133424
# ARIMA(0, 0, 1)X(1, 0, 1, 12)12-AIC:2601.8946262505874
# ARIMA(0, 0, 1)X(1, 1, 0, 12)12-AIC:348.9629654896913
# ARIMA(0, 0, 1)X(1, 1, 1, 12)12-AIC:320.29190309242784
# ARIMA(0, 1, 0)X(0, 0, 0, 12)12-AIC:659.99279584349
# ARIMA(0, 1, 0)X(0, 0, 1, 12)12-AIC:1661.4983629877324
# ARIMA(0, 1, 0)X(0, 1, 0, 12)12-AIC:512.8891324060335
# ARIMA(0, 1, 0)X(0, 1, 1, 12)12-AIC:327.40565514190814
# ARIMA(0, 1, 0)X(1, 0, 0, 12)12-AIC:498.42200313343324
# ARIMA(0, 1, 0)X(1, 0, 1, 12)12-AIC:1375.2670654679707
# ARIMA(0, 1, 0)X(1, 1, 0, 12)12-AIC:341.1748879933388
# ARIMA(0, 1, 0)X(1, 1, 1, 12)12-AIC:328.2637931440448
# ARIMA(0, 1, 1)X(0, 0, 0, 12)12-AIC:624.5202766655299
# ARIMA(0, 1, 1)X(0, 0, 1, 12)12-AIC:1854.8570433348648
# ARIMA(0, 1, 1)X(0, 1, 0, 12)12-AIC:475.51372288803924
# ARIMA(0, 1, 1)X(0, 1, 1, 12)12-AIC:301.31285543385593
# ARIMA(0, 1, 1)X(1, 0, 0, 12)12-AIC:483.8632623669214
# ARIMA(0, 1, 1)X(1, 0, 1, 12)12-AIC:2053.660390769928
# ARIMA(0, 1, 1)X(1, 1, 0, 12)12-AIC:330.02606011494095
# ARIMA(0, 1, 1)X(1, 1, 1, 12)12-AIC:303.00779884315887
# ARIMA(1, 0, 0)X(0, 0, 0, 12)12-AIC:673.5984842473428
# ARIMA(1, 0, 0)X(0, 0, 1, 12)12-AIC:1556.085286250032
# ARIMA(1, 0, 0)X(0, 1, 0, 12)12-AIC:503.2394508206441
# ARIMA(1, 0, 0)X(0, 1, 1, 12)12-AIC:332.0128233996347
# ARIMA(1, 0, 0)X(1, 0, 0, 12)12-AIC:499.6059898016764
# ARIMA(1, 0, 0)X(1, 0, 1, 12)12-AIC:1196.4412514730893
# ARIMA(1, 0, 0)X(1, 1, 0, 12)12-AIC:332.1460416698548
# ARIMA(1, 0, 0)X(1, 1, 1, 12)12-AIC:334.0472005458043
# ARIMA(1, 0, 1)X(0, 0, 0, 12)12-AIC:635.7316183720088
# ARIMA(1, 0, 1)X(0, 0, 1, 12)12-AIC:2326.5841223758907
# ARIMA(1, 0, 1)X(0, 1, 0, 12)12-AIC:491.2449053857168
# ARIMA(1, 0, 1)X(0, 1, 1, 12)12-AIC:317.2198971657947
# ARIMA(1, 0, 1)X(1, 0, 0, 12)12-AIC:482.3989138361717
# ARIMA(1, 0, 1)X(1, 0, 1, 12)12-AIC:2611.3052801178637
# ARIMA(1, 0, 1)X(1, 1, 0, 12)12-AIC:331.19344507776333
# ARIMA(1, 0, 1)X(1, 1, 1, 12)12-AIC:318.5558598179608
# ARIMA(1, 1, 0)X(0, 0, 0, 12)12-AIC:637.821368372901
# ARIMA(1, 1, 0)X(0, 0, 1, 12)12-AIC:1666.2012040925151
# ARIMA(1, 1, 0)X(0, 1, 0, 12)12-AIC:495.6144248030722
# ARIMA(1, 1, 0)X(0, 1, 1, 12)12-AIC:318.77351360343215
# ARIMA(1, 1, 0)X(1, 0, 0, 12)12-AIC:472.01548958282035
# ARIMA(1, 1, 0)X(1, 0, 1, 12)12-AIC:1470.4123655131127
# ARIMA(1, 1, 0)X(1, 1, 0, 12)12-AIC:319.80388762697316
# ARIMA(1, 1, 0)X(1, 1, 1, 12)12-AIC:320.5845039586683
# ARIMA(1, 1, 1)X(0, 0, 0, 12)12-AIC:625.7503341420866
# ARIMA(1, 1, 1)X(0, 0, 1, 12)12-AIC:2550.647044653832
# ARIMA(1, 1, 1)X(0, 1, 0, 12)12-AIC:476.18713808304113
# ARIMA(1, 1, 1)X(0, 1, 1, 12)12-AIC:303.23526185764524
# ARIMA(1, 1, 1)X(1, 0, 0, 12)12-AIC:473.4544422326877
# ARIMA(1, 1, 1)X(1, 0, 1, 12)12-AIC:1335.9994770924786
# ARIMA(1, 1, 1)X(1, 1, 0, 12)12-AIC:318.98701197393535
# ARIMA(1, 1, 1)X(1, 1, 1, 12)12-AIC:304.9306974448284

# %%
train=office_supplies.iloc[:-20]
test=office_supplies.iloc[-20:]
print(train.shape,test.shape)
# Out:
# (28, 1) (20, 1)

# %%
test=test.groupby('Order Date')['Sales'].sum().reset_index()
test=test.set_index('Order Date')
test
# Out:
#                   Sales
# Order Date
# 2017-05-01   585.299321
# 2017-06-01   432.782440
# 2017-07-01   539.620609
# 2017-08-01   451.287640
# 2017-09-01   559.121958
# 2017-10-01   877.068000
# 2017-11-01   586.027154
# 2017-12-01  1026.205538
# 2018-01-01   853.153520
# 2018-02-01   659.403136
# 2018-03-01   660.929429
# 2018-04-01   351.840040
# 2018-05-01   555.389769
# 2018-06-01   560.771923
# 2018-07-01   571.201560
# 2018-08-01  1378.194154
# 2018-09-01   994.999643
# 2018-10-01   854.620462
# 2018-11-01  1005.800077
# 2018-12-01   780.914071

# %%
mod =sm.tsa.statespace.SARIMAX(train['Sales'],order=(1,1,1),seasonal_order=(1,1,1,12),enforce_invertibility=False)
results=mod.fit()
print(results.summary().tables[1])
results.plot_diagnostics()
plt.show()
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7769      0.771     -1.007      0.314      -2.288       0.735
# ma.L1         -0.4684      0.527     -0.889      0.374      -1.501       0.564
# ar.S.L12      -0.9111      3.105     -0.293      0.769      -6.998       5.175
# ma.S.L12      -0.1817     23.212     -0.008      0.994     -45.676      45.313
# sigma2      1.649e+04   8.09e+04      0.204      0.838   -1.42e+05    1.75e+05
# ==============================================================================

# %%
start=len(train)
end=len(train)+len(test)-1
pred=results.predict(start=start,end=end,typ='levels')
pred.index=office_supplies.index[start:end+1]
print(pred)
# Out:
# Order Date
# 2017-05-01    1163.056115
# 2017-06-01     644.193817
# 2017-07-01    1101.514650
# 2017-08-01     643.826986
# 2017-09-01    1320.403099
# 2017-10-01     587.308228
# 2017-11-01    1215.082645
# 2017-12-01     836.188026
# 2018-01-01     568.731756
# 2018-02-01     614.594964
# 2018-03-01     930.908912
# 2018-04-01     833.690146
# 2018-05-01     745.855411
# 2018-06-01     876.012059
# 2018-07-01     626.330165
# 2018-08-01     832.746727
# 2018-09-01     973.304879
# 2018-10-01     795.317426
# 2018-11-01    1078.371978
# 2018-12-01     689.507773
# Name: predicted_mean, dtype: float64

# %%
pred.plot(legend=True)
test['Sales'].plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(pred,test)
# Out:
# 133420.39943395887

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse=sqrt(mean_squared_error(pred,test))
print(rmse)
# Out:
# 365.2675723821632

# %%
mod =sm.tsa.statespace.SARIMAX(office_supplies['Sales'],order=(1,1,1),seasonal_order=(1,1,1,12),enforce_invertibility=False)
results2=mod.fit()

# %%
office_supplies.tail()
# Out:
#                   Sales
# Order Date
# 2018-08-01  1378.194154
# 2018-09-01   994.999643
# 2018-10-01   854.620462
# 2018-11-01  1005.800077
# 2018-12-01   780.914071

# %%
pred1=results2.get_forecast(steps=72)
predc=pred1.conf_int()
ax=office_supplies.plot(label='observed',figsize=(14,7))
pred1.predicted_mean.plot(ax=ax,label='Forecast')
ax.fill_between(predc.index,predc.iloc[:,0],predc.iloc[:,1],color='k',alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Office Supplies Sales')
plt.legend()
plt.show()
